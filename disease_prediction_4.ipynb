# %%
# %store -r
df
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 36267  51790  18229       1     152    53.0    115     50            2     2
# 16203  23140  14390       1     157    61.0     90     50            2     1
# 34533  49328  18128       1     156    54.0     90     50            1     1
# 68370  97651  19066       2     159    68.0    100     50            2     1
# 29662  42406  14634       1     162    53.0    100     50            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 35030  50043  23394       1     170   152.0    200    140            1     3
# 49523  70708  20330       1     162    67.0    200    140            1     3
# 36473  52100  19883       2     172    89.0    210    140            2     2
# 32424  46309  16986       2     170    90.0    160    140            1     1
# 53889  76875  20281       2     170    90.0    210    140            1     1
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig, ax=plt.subplots(2, 2, figsize=(10,8))

df.sort_values("ap_lo", inplace=True)
sns.barplot(df, x="cardio", hue="HBP", ax=ax[0,0])
df.sort_values("BMI", inplace=True)
sns.barplot(df, x="cardio", hue="Obesity", ax=ax[0,1])
sns.histplot(df, x="age", hue="cardio", ax=ax[1,0], multiple="stack", binwidth=730)
sns.barplot(df, x="cardio", hue="cholesterol", ax=ax[1,1])
# Out:
# <Axes: xlabel='cardio'>

# %%
for i,j in zip(["normal range", "overweight", "obese class I", "obese class II", "obese class III"], range(1,6)):
    df["Obesity"]=df["Obesity"].apply(lambda x: j if x == i else x)
for i,j in zip(["normal range", "overweight", "obese class I", "obese class II", "obese class III"], range(1,6)):
    df["Obesity"]=df["Obesity"].apply(lambda x: j if x == i else x)

df
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 58200  83048  22544       1     169    35.0    140     90            2     1
# 16322  23318  21872       1     165    35.0    100     70            1     1
# 38417  54851  21809       1     154    32.0    110     60            1     1
# 9487   13518  20958       2     172    40.0    140     90            1     2
# 10447  14908  22007       1     162    38.0    100     70            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 3413    4825  14585       1     159   159.0    100     80            1     1
# 51909  74028  23228       1     142   129.0    140     90            1     3
# 2458    3470  23646       2     159   165.0    130     70            1     1
# 20092  28683  20656       2     165   178.0    120     80            1     1
# 61788  88220  18956       2     165   178.0    120     80            1     1
#
# ...
