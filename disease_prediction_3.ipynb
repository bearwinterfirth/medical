# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# källa: https://stackoverflow.com/questions/62063745/moving-dataframes-between-notebooks
# %store -r
df
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 36267  51790  18229       1     152    53.0    115     50            2     2
# 16203  23140  14390       1     157    61.0     90     50            2     1
# 34533  49328  18128       1     156    54.0     90     50            1     1
# 68370  97651  19066       2     159    68.0    100     50            2     1
# 29662  42406  14634       1     162    53.0    100     50            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 35030  50043  23394       1     170   152.0    200    140            1     3
# 49523  70708  20330       1     162    67.0    200    140            1     3
# 36473  52100  19883       2     172    89.0    210    140            2     2
# 32424  46309  16986       2     170    90.0    160    140            1     1
# 53889  76875  20281       2     170    90.0    210    140            1     1
#
# ...

# %%
df.sort_values("ap_hi")
df.tail()
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 35030  50043  23394       1     170   152.0    200    140            1     3
# 49523  70708  20330       1     162    67.0    200    140            1     3
# 36473  52100  19883       2     172    89.0    210    140            2     2
# 32424  46309  16986       2     170    90.0    160    140            1     1
# 53889  76875  20281       2     170    90.0    210    140            1     1
#
#        smoke  alco  active  cardio        BMI          Obesity  \
# 35030      0     0       1       1  52.595156  obese class III
# 49523      0     0       1       1  25.529645       overweight
# 36473      0     1       1       1  30.083829    obese class I
# 32424      1     0       1       1  31.141869    obese class I
# 53889      1     0       1       1  31.141869    obese class I
#
#                        HBP
# 35030  hypertension crisis
# 49523  hypertension crisis
# 36473  hypertension crisis
# ...

# %%
df=df[df["ap_hi"]<1000]

# %%
sns.histplot(df[df["ap_hi"]>100]["ap_hi"], binwidth=10)
# Out:
# <Axes: xlabel='ap_hi', ylabel='Count'>

# %%
df.sort_values("ap_hi")
df.tail(25)
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 25031  35750  20963       2     164   106.0    150    130            3     1
# 38990  55670  18830       1     160    98.0    160    130            1     1
# 14903  21311  18903       2     178   115.0    200    130            3     3
# 28987  41419  21031       1     152    80.0    190    130            3     2
# 55751  79553  21920       1     161    63.0    200    130            1     1
# 28334  40500  23425       2     175    75.0    180    130            2     1
# 33235  47497  20376       1     159   100.0    200    130            3     2
# 17563  25088  21155       1     156   106.0    180    130            1     1
# 7676   10958  20508       1     156    70.0    170    130            1     1
# 65080  92892  17564       2     171   123.0    195    130            3     2
# 49003  69958  21204       2     153    83.0    200    130            2     1
# ...

# %%
df=df[df["ap_hi"]<250]

# %%
df.sort_values("ap_hi")
df.head(25)
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 36267  51790  18229       1     152    53.0    115     50            2     2
# 16203  23140  14390       1     157    61.0     90     50            2     1
# 34533  49328  18128       1     156    54.0     90     50            1     1
# 68370  97651  19066       2     159    68.0    100     50            2     1
# 29662  42406  14634       1     162    53.0    100     50            1     1
# 24925  35604  17567       1     151    46.0    100     50            1     1
# 59044  84283  14608       1     160    58.0     80     50            2     1
# 39718  56759  18927       1     162    51.0     90     50            1     1
# 43233  61755  18186       2     172    75.0     80     50            2     2
# 45554  65075  17294       1     156    55.0     90     50            1     1
# 28026  40071  15858       2     163    61.0     80     50            1     1
# ...

# %%
sns.histplot(df[df["ap_hi"]<100]["ap_hi"], binwidth=5)
# Out:
# <Axes: xlabel='ap_hi', ylabel='Count'>

# %%
df=df[df["ap_hi"]>50]
sns.histplot(df[df["ap_hi"]<100]["ap_hi"], binwidth=5)
# Out:
# <Axes: xlabel='ap_hi', ylabel='Count'>

# %%
df.sort_values("ap_lo", inplace=True)
df.head()
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 36267  51790  18229       1     152    53.0    115     50            2     2
# 16203  23140  14390       1     157    61.0     90     50            2     1
# 24925  35604  17567       1     151    46.0    100     50            1     1
# 59044  84283  14608       1     160    58.0     80     50            2     1
# 39718  56759  18927       1     162    51.0     90     50            1     1
#
#        smoke  alco  active  cardio        BMI       Obesity      HBP
# 36267      0     0       1       0  22.939751  normal range  healthy
# 16203      0     0       1       1  24.747454  normal range  healthy
# 24925      0     0       1       0  20.174554  normal range  healthy
# 59044      0     0       1       0  22.656250  normal range  healthy
# 39718      0     0       0       0  19.433013  normal range  healthy

# %%
sns.histplot(df[df["ap_lo"]<70]["ap_lo"], binwidth=2)
# Out:
# <Axes: xlabel='ap_lo', ylabel='Count'>

# %%
df=df[df["ap_lo"]>49]
sns.histplot(df[df["ap_lo"]<80]["ap_lo"], binwidth=2)
# Out:
# <Axes: xlabel='ap_lo', ylabel='Count'>

# %%
sns.histplot(df[df["ap_lo"]>300]["ap_lo"], binwidth=100)
# Out:
# <Axes: >

# %%
df=df[df["ap_lo"]<150]
sns.histplot(df[df["ap_lo"]<150]["ap_lo"], binwidth=5)
# Out:
# <Axes: xlabel='ap_lo', ylabel='Count'>

# %%
df=df[df["ap_lo"]<df["ap_hi"]]
df=df[df["ap_hi"]-df["ap_lo"]<80]

# %%
df.sort_values("ap_lo", inplace=True)
df.head(25)
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 36267  51790  18229       1     152    53.0    115     50            2     2
# 16203  23140  14390       1     157    61.0     90     50            2     1
# 43233  61755  18186       2     172    75.0     80     50            2     2
# 45554  65075  17294       1     156    55.0     90     50            1     1
# 28026  40071  15858       2     163    61.0     80     50            1     1
# 68370  97651  19066       2     159    68.0    100     50            2     1
# 29662  42406  14634       1     162    53.0    100     50            1     1
# 34533  49328  18128       1     156    54.0     90     50            1     1
# 59044  84283  14608       1     160    58.0     80     50            2     1
# 39718  56759  18927       1     162    51.0     90     50            1     1
# 24925  35604  17567       1     151    46.0    100     50            1     1
# ...

# %%
df.describe()
# Out:
#                  id           age        gender        height        weight  \
# count  66938.000000  66938.000000  66938.000000  66938.000000  66938.000000
# mean   50003.315381  19443.165735      1.347799    164.454973     73.963457
# std    28848.643559   2469.397738      0.476276      7.817056     14.175872
# min        0.000000  10798.000000      1.000000    131.000000     30.000000
# 25%    25024.500000  17631.000000      1.000000    159.000000     65.000000
# 50%    50071.000000  19690.000000      1.000000    165.000000     72.000000
# 75%    74906.500000  21309.000000      2.000000    170.000000     82.000000
# max    99999.000000  23713.000000      2.000000    207.000000    200.000000
#
#               ap_hi         ap_lo   cholesterol          gluc         smoke  \
# count  66938.000000  66938.000000  66938.000000  66938.000000  66938.000000
# mean     125.572784     81.176268      1.359781      1.223236      0.087723
# ...

# %%
def high_blood_pressure(sys, dia):
    if sys<120 and dia<80:
        return "healthy"
    elif sys<130 and dia<80:
        return "elevated"
    elif sys<140 or (dia>=80 and dia<90):
        return "hypertension 1"
    elif (sys>=140 and sys<180) or (dia>=90 and dia<120):
        return "hypertension 2"
    else:
        return "hypertension crisis"
    
df["HBP"]=df.apply(lambda x: high_blood_pressure(x["ap_hi"], x["ap_lo"]), axis=1)

df
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 36267  51790  18229       1     152    53.0    115     50            2     2
# 16203  23140  14390       1     157    61.0     90     50            2     1
# 43233  61755  18186       2     172    75.0     80     50            2     2
# 45554  65075  17294       1     156    55.0     90     50            1     1
# 28026  40071  15858       2     163    61.0     80     50            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 35030  50043  23394       1     170   152.0    200    140            1     3
# 49523  70708  20330       1     162    67.0    200    140            1     3
# 36473  52100  19883       2     172    89.0    210    140            2     2
# 32424  46309  16986       2     170    90.0    160    140            1     1
# 53889  76875  20281       2     170    90.0    210    140            1     1
#
# ...

# %%
# %store df
# Out:
# Stored 'df' (DataFrame)
